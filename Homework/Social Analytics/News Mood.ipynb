# %%
import tweepy
import json
import numpy as np
from datetime import datetime
import time
import matplotlib.pyplot as plt
import os
import pandas as pd
from dateutil import parser
from datetime import timedelta
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
consumer_key = "Ed4RNulN1lp7AbOooHa9STCoU"
consumer_secret = "P7cUJlmJZq0VaCY0Jg7COliwQqzK0qYEyUF9Y0idx4ujb3ZlW5"
access_token = "839621358724198402-dzdOsx2WWHrSuBwyNUiqSEnTivHozAZ"
access_token_secret = "dCZ80uNRbFDjxdU2EckmNiSckdoATach6Q8zb7YYYE5ER"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
target_user = ("@BBC")
# Counter
counter = 1

# Variables for holding sentiments
bbcsentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        bbcsentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "User Account": target_user,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1

# %%
bbcsentiments_pd = pd.DataFrame.from_dict(bbcsentiments)
bbcsentiments_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.7939  Wed Jan 31 20:55:48 +0000 2018     0.739      0.0     0.261
# 1    0.0000  Wed Jan 31 20:54:41 +0000 2018     1.000      0.0     0.000
# 2    0.0000  Wed Jan 31 20:05:02 +0000 2018     1.000      0.0     0.000
# 3    0.1680  Wed Jan 31 19:05:35 +0000 2018     0.920      0.0     0.080
# 4    0.5411  Wed Jan 31 19:04:29 +0000 2018     0.720      0.0     0.280
#
#    Tweets Ago User Account
# 0           1         @BBC
# 1           2         @BBC
# 2           3         @BBC
# 3           4         @BBC
# 4           5         @BBC

# %%
plt.scatter(np.arange(len(bbcsentiments_pd["Compound"])),
         bbcsentiments_pd["Compound"], marker="o", color="orange", edgecolor="black", linewidth=0.5,
         alpha=0.8)

# # Incorporate the other graph properties
plt.title("Sentiment Analysis of Tweets (%s) for %s" % (time.strftime("%x"), target_user))
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.savefig("Sentiment Analysis of Tweets BBC.png")
plt.show()

# %%
target_user = ("@CBS")

# Counter
counter = 1

# Variables for holding sentiments
cbssentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        cbssentiments.append({"Date": tweet["created_at"],
                           "User Account": target_user,
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1

# %%
cbssentiments_pd = pd.DataFrame.from_dict(cbssentiments)
cbssentiments_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.1139  Wed Jan 31 21:42:15 +0000 2018     0.912    0.000     0.088
# 1    0.1007  Wed Jan 31 17:05:47 +0000 2018     0.750    0.115     0.135
# 2    0.4588  Wed Jan 31 16:37:17 +0000 2018     0.812    0.000     0.188
# 3    0.1779  Wed Jan 31 06:55:30 +0000 2018     0.779    0.095     0.126
# 4   -0.2263  Wed Jan 31 02:15:16 +0000 2018     0.569    0.252     0.179
#
#    Tweets Ago User Account
# 0           1         @CBS
# 1           2         @CBS
# 2           3         @CBS
# 3           4         @CBS
# 4           5         @CBS

# %%
plt.scatter(np.arange(len(cbssentiments_pd["Compound"])),
         cbssentiments_pd["Compound"], marker="o", color="blue", edgecolor="black", linewidth=0.5,
         alpha=0.8)

# # Incorporate the other graph properties
plt.title("Sentiment Analysis of Tweets (%s) for %s" % (time.strftime("%x"), target_user))
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.savefig("Sentiment Analysis of Tweets CBS.png")
plt.show()

# %%
target_user = ("@CNN")

# Counter
counter = 1

# Variables for holding sentiments
cnnsentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        cnnsentiments.append({"Date": tweet["created_at"],  
                           "User Account": target_user,
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1

# %%
cnnsentiments_pd = pd.DataFrame.from_dict(cnnsentiments)
cnnsentiments_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Thu Feb 01 05:20:07 +0000 2018     1.000    0.000       0.0
# 1    0.0000  Thu Feb 01 05:15:13 +0000 2018     1.000    0.000       0.0
# 2    0.0000  Thu Feb 01 05:05:12 +0000 2018     1.000    0.000       0.0
# 3   -0.3400  Thu Feb 01 04:50:07 +0000 2018     0.888    0.112       0.0
# 4   -0.7003  Thu Feb 01 04:49:08 +0000 2018     0.721    0.279       0.0
#
#    Tweets Ago User Account
# 0           1         @CNN
# 1           2         @CNN
# 2           3         @CNN
# 3           4         @CNN
# 4           5         @CNN

# %%
plt.scatter(np.arange(len(cnnsentiments_pd["Compound"])),
         cnnsentiments_pd["Compound"], marker="o", color="yellow", edgecolor="black", linewidth=0.5, alpha=0.8)

# # Incorporate the other graph properties
plt.title("Sentiment Analysis of Tweets (%s) for %s" % (time.strftime("%x"), target_user))
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.savefig("Sentiment Analysis of Tweets CNN.png")
plt.show()

# %%
target_user = ("@FoxNews")

counter = 1

# Variables for holding sentiments
foxsentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        foxsentiments.append({"Date": tweet["created_at"],
                           "User Account": target_user,
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1

# %%
foxsentiments_pd = pd.DataFrame.from_dict(foxsentiments)
foxsentiments_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.4019  Thu Feb 01 05:25:00 +0000 2018     0.812    0.188     0.000
# 1    0.5187  Thu Feb 01 05:20:02 +0000 2018     0.814    0.000     0.186
# 2   -0.4404  Thu Feb 01 05:15:00 +0000 2018     0.805    0.195     0.000
# 3    0.0000  Thu Feb 01 05:10:05 +0000 2018     1.000    0.000     0.000
# 4   -0.6808  Thu Feb 01 05:05:00 +0000 2018     0.641    0.359     0.000
#
#    Tweets Ago User Account
# 0           1     @FoxNews
# 1           2     @FoxNews
# 2           3     @FoxNews
# 3           4     @FoxNews
# 4           5     @FoxNews

# %%
plt.scatter(np.arange(len(foxsentiments_pd["Compound"])),
         foxsentiments_pd["Compound"], marker="o", color="red", edgecolor="black", linewidth=0.5,
         alpha=0.8)

# # Incorporate the other graph properties
plt.title("Sentiment Analysis of Tweets (%s) for %s" % (time.strftime("%x"), target_user))
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.savefig("Sentiment Analysis of Tweets FOX.png")
plt.show()

# %%
target_user = ("@nytimes")
# Counter
counter = 1

# Variables for holding sentiments
nytsentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweet into an array
        nytsentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "User Account": user,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter = counter + 1

# %%
nytsentiments_pd = pd.DataFrame.from_dict(nytsentiments)
nytsentiments_pd.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.1027  Thu Feb 01 05:18:05 +0000 2018     0.802    0.090     0.108
# 1   -0.5574  Thu Feb 01 05:03:01 +0000 2018     0.825    0.175     0.000
# 2    0.0000  Thu Feb 01 04:48:02 +0000 2018     1.000    0.000     0.000
# 3    0.0000  Thu Feb 01 04:33:07 +0000 2018     1.000    0.000     0.000
# 4    0.2960  Thu Feb 01 04:18:05 +0000 2018     0.913    0.000     0.087
#
#    Tweets Ago User Account
# 0           1     @Nytimes
# 1           2     @Nytimes
# 2           3     @Nytimes
# 3           4     @Nytimes
# 4           5     @Nytimes

# %%
plt.scatter(np.arange(len(nytsentiments_pd["Compound"])),
         nytsentiments_pd["Compound"], marker="o", color="green", edgecolor="black", linewidth=0.5,
         alpha=0.8)

# # Incorporate the other graph properties
plt.title("Sentiment Analysis of Tweets (%s) for %s" % (time.strftime("%x"), target_user))
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.savefig("Sentiment Analysis of Tweets NYT.png")
plt.show()

# %%
plt.figure(figsize = (10, 10))

plt.scatter(np.arange(len(bbcsentiments_pd["Compound"])),
         bbcsentiments_pd["Compound"], marker="o", color="orange", edgecolor="black", linewidth=0.5,
         alpha=0.8, label="BBC")
plt.scatter(np.arange(len(cbssentiments_pd["Compound"])),
         cbssentiments_pd["Compound"], marker="o", color="blue", edgecolor="black", linewidth=0.5,
         alpha=0.8, label="CBS")
plt.scatter(np.arange(len(cnnsentiments_pd["Compound"])),
         cnnsentiments_pd["Compound"], marker="o", color="yellow", edgecolor="black", linewidth=0.5, alpha=0.8, label="CNN")
plt.scatter(np.arange(len(foxsentiments_pd["Compound"])),
         foxsentiments_pd["Compound"], marker="o", color="red", edgecolor="black", linewidth=0.5, label="FOX",
         alpha=0.8)
plt.scatter(np.arange(len(nytsentiments_pd["Compound"])),
         nytsentiments_pd["Compound"], marker="o", color="green", edgecolor="black", linewidth=0.5,
         alpha=0.8, label="NYT")
plt.title("Sentiment Analysis of Tweets")
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.legend()
plt.savefig("Sentiment Analysis of Tweets Combined.png")
plt.show()

# %%
target_user = ("@BBC")
# Counter
compound_list = []
positive_list = []
negative_list = []
neutral_list = []

# Loop through 10 pages of tweets (total 200 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets
    for tweet in public_tweets:

        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]

        # Add each value to the appropriate list
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)

# Print the Averages
print("")
print("User: %s" % target_user)
print(f"Compound: {np.mean(compound_list)}")
print(f"Positive: {np.mean(positive_list)}")
print(f"Neutral: {np.mean(neutral_list)}")
print(f"Negative: {np.mean(negative_list)}")
# Out:
# User: @BBC
# Compound: 0.34363499999999997
# Positive: 0.12835000000000002
# Neutral: 0.8626999999999999
# Negative: 0.00895

# %%
target_user = ("@CBS")
compound_list = []
positive_list = []
negative_list = []
neutral_list = []

# Loop through 10 pages of tweets (total 200 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets
    for tweet in public_tweets:

        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]

        # Add each value to the appropriate list
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)

# Print the Averages
print("")
print("User: %s" % target_user)
print(f"Compound: {np.mean(compound_list)}")
print(f"Positive: {np.mean(positive_list)}")
print(f"Neutral: {np.mean(neutral_list)}")
print(f"Negative: {np.mean(negative_list)}")
# Out:
# User: @CBS
# Compound: 0.3905400000000001
# Positive: 0.23475
# Neutral: 0.7034999999999999
# Negative: 0.061750000000000006

# %%
target_user = ("@CNN")
compound_list = []
positive_list = []
negative_list = []
neutral_list = []

# Loop through 10 pages of tweets (total 200 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets
    for tweet in public_tweets:

        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]

        # Add each value to the appropriate list
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)

# Print the Averages
print("")
print("User: %s" % target_user)
print(f"Compound: {np.mean(compound_list)}")
print(f"Positive: {np.mean(positive_list)}")
print(f"Neutral: {np.mean(neutral_list)}")
print(f"Negative: {np.mean(negative_list)}")
# Out:
# User: @CNN
# Compound: -0.010220000000000005
# Positive: 0.07535
# Neutral: 0.8603000000000001
# Negative: 0.06434999999999999

# %%
target_user = ("@FoxNews")
compound_list = []
positive_list = []
negative_list = []
neutral_list = []

# Loop through 10 pages of tweets (total 200 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets
    for tweet in public_tweets:

        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]

        # Add each value to the appropriate list
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)

# Print the Averages
print("")
print("User: %s" % target_user)
print(f"Compound: {np.mean(compound_list)}")
print(f"Positive: {np.mean(positive_list)}")
print(f"Neutral: {np.mean(neutral_list)}")
print(f"Negative: {np.mean(negative_list)}")
# Out:
# User: @FoxNews
# Compound: -0.09655999999999999
# Positive: 0.047599999999999996
# Neutral: 0.8564
# Negative: 0.09604999999999998

# %%
target_user = ("@nytimes")
compound_list = []
positive_list = []
negative_list = []
neutral_list = []

# Loop through 10 pages of tweets (total 200 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user)

    # Loop through all tweets
    for tweet in public_tweets:

        # Run Vader Analysis on each tweet
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]

        # Add each value to the appropriate list
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)

# Print the Averages
print("")
print("User: %s" % target_user)
print(f"Compound: {np.mean(compound_list)}")
print(f"Positive: {np.mean(positive_list)}")
print(f"Neutral: {np.mean(neutral_list)}")
print(f"Negative: {np.mean(negative_list)}")
# Out:
# User: @nytimes
# Compound: 0.05369000000000001
# Positive: 0.08265
# Neutral: 0.86605
# Negative: 0.05125

# %%
users = ('BBC', 'CBS', 'CNN', 'FOX', 'NYT')
compound = [0.34363,-0.01022,-0.10546,-0.09655, 0.05369]
x_axis = (-0.6,.6)
 
plt.bar(users,compound, align ='center', alpha=0.5)

plt.ylabel('Tweet Polarity')
plt.title('Overall Media Sentiment')
plt.savefig("Overall Media Sentiment.png")
plt.show()

# %% [markdown]
# I ran this report several times. The final submission is the day after the State of the Union. Fox consistenly scored lowest in sentiment scores along with CNN. There was one exception. The hours following the State of the Union, the compound score for Fox was the highest noted for Fox. BBC demonstrated consistent higher sentiment compound scores. Fox and CNN had noticeable patterns in their compound scores in the morning. For example, every 12th tweet was negative and had exactly the same score. Overall, all sentiment scores are more positive in the AM and are lowest in the evening. Start your day cheery!
